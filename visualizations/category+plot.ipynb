# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('ggplot')

# %%
df = pd.read_csv('/data/category_year.csv')

# %%
df.head()
# Out:
#                             agency_index       2000        2001         2002  \
# 0                                    NaN        NaN         NaN          NaN
# 1   AGENCY FOR INTERNATIONAL DEVELOPMENT        NaN  8601959.15  18885754.00
# 2             AGRICULTURE, DEPARTMENT OF  125068.32  4355265.87   5034934.63
# 3   AMERICAN BATTLE MONUMENTS COMMISSION        NaN         NaN          NaN
# 4           ARMED FORCES RETIREMENT HOME       0.00        0.00         0.00
#
#           2003          2004          2005          2006          2007  \
# 0          NaN           NaN           NaN           NaN           NaN
# 1  22310522.62  2.500578e+07  3.902678e+07  5.365248e+07  1.089095e+08
# 2  33149578.34  2.494171e+08  1.327417e+08  1.125992e+08  1.122482e+08
# 3          NaN  8.708630e+03           NaN           NaN           NaN
# 4         0.00           NaN           NaN           NaN           NaN
#
# ...

# %%
df = df.fillna(0)
df = df.iloc[1:,:].copy()
df = df.set_index('agency_index')
df = df.transpose()

# %%
df
# Out:
# agency_index   AGENCY FOR INTERNATIONAL DEVELOPMENT  \
# 2000                                   0.000000e+00
# 2001                                   8.601959e+06
# 2002                                   1.888575e+07
# 2003                                   2.231052e+07
# 2004                                   2.500578e+07
# 2005                                   3.902678e+07
# 2006                                   5.365248e+07
# 2007                                   1.089095e+08
# 2008                                   4.631357e+07
# 2009                                   0.000000e+00
# 2010                                   8.297702e+06
# 2011                                   0.000000e+00
# 2012                                   0.000000e+00
# 2013                                   0.000000e+00
# 2014                                   3.933060e+06
# 2015                                   0.000000e+00
# 2016                                   2.164959e+07
#
# ...

# %%
df.plot(kind='bar',stacked=True,figsize=(15,10))
plt.legend([''])
plt.show()
