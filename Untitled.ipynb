# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
dat = pd.read_csv("govt2000_2012/GovernmentSpendingContracts-2012.csv", nrows = 100)

# %%
dat.head()
# Out:
#               unique_transaction_id transaction_status  dollars_obligated  \
# 0  ac27b56021ce3cdb8c8673a003a9bc1b             active            6800.00
# 1  3a84df75bfbdc39215e3852629e5677e             active             433.60
# 2  fecc36869d390b4e84ee6299561b236c             active            3522.99
# 3  6e5c5249db52994d43451cba604db225             active           13170.24
# 4  0bcb5ebf8323f2c0adb80e01a018a6bf             active               0.00
#
#    base_and_exercised_options_value  base_and_all_options_value  \
# 0                           6800.00                     6800.00
# 1                            433.60                      433.60
# 2                           3522.99                     3522.99
# 3                          13170.24                    13170.24
# 4                           5400.00                     5400.00
#
#           maj_agency_cat                      mod_agency  \
# 0  9700: DEPT OF DEFENSE          2100: DEPT OF THE ARMY
# ...

# %%
dat2 = dat.loc[:,['maj_agency_cat','base_and_all_options_value','number_of_offers_received']]

dat2
# Out:
#                            maj_agency_cat  base_and_all_options_value  \
# 0                   9700: DEPT OF DEFENSE                     6800.00
# 1                   9700: DEPT OF DEFENSE                      433.60
# 2                   9700: DEPT OF DEFENSE                     3522.99
# 3                   9700: DEPT OF DEFENSE                    13170.24
# 4                   9700: DEPT OF DEFENSE                     5400.00
# 5                   9700: DEPT OF DEFENSE                    15150.00
# 6                   9700: DEPT OF DEFENSE                     8543.29
# 7                   9700: DEPT OF DEFENSE                        0.00
# 8                   9700: DEPT OF DEFENSE                   302483.80
# 9   4700: GENERAL SERVICES ADMINISTRATION                    22850.00
# 10                  9700: DEPT OF DEFENSE                     3286.40
# 11  4700: GENERAL SERVICES ADMINISTRATION                        0.00
# ...

# %%
dat3 = dat2.loc[:,['number_of_offers_received']]
dat3.plot.hist(bins = 800)
axes = plt.gca()
axes.set_xlim([0,100])
plt.figure()
# Out:
# /home/jason_kuo4/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
x = np.random.normal(size=100)
plt.xlim(0, 100)
sns.distplot(dat3, bins = 999);
# Out:
# /home/jason_kuo4/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Out:
# 0
# 3
